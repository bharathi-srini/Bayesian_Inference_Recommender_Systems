# %%
import numpy as np
import pandas as pd
import os
import argparse
from sklearn import preprocessing
from sklearn.preprocessing import OneHotEncoder, MinMaxScaler, StandardScaler
from sklearn.model_selection import train_test_split
import time

from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import Adam
from keras.layers import Input,Activation, concatenate, Embedding, Reshape
from keras.layers import Merge, Flatten, merge, Lambda, Dropout
from keras.layers.normalization import BatchNormalization
from keras.models import Model
from keras.models import model_from_json
from keras.models import load_model
from keras.regularizers import l2, l1_l2
import tensorflow as tf
import gc
# Out:
# /Users/BharathiSrinivasan/anaconda2/envs/python36/lib/python3.6/site-packages/h5py/__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
#Importing Instacart data
df_full = pd.read_csv('/Users/BharathiSrinivasan/Documents/GitHub/Thesis/merged_data.csv', index_col = False)

# %%
#Sampling a fraction for data for initial training
df_small = df_full.sample(frac = 0.01)
print(df_small.shape)
# Out:
# (338191, 14)

# %%
#Investigating NAs
print(df_small.isnull().sum().sum())
# Out:
# 0

# %%
CATEGORICAL_COLUMNS = ["order_dow", "order_hour_of_day"]
CONTINUOUS_COLUMNS = ["days_since_prior_order","order_number","add_to_cart_order"]
EMBEDDING_COLUMNS = ["user_id", "product_id","aisle_id","department_id"]

# %%
#One-hot encoding categorical columns
df_small = pd.get_dummies(df_small, columns=[x for x in CATEGORICAL_COLUMNS])

# %%
#Normalising the feature columns
df_small[CONTINUOUS_COLUMNS] = MinMaxScaler().fit_transform(df_small[CONTINUOUS_COLUMNS].values)

# %%
#Drop product names and department names for the time being! Incorporate as embedded vectors later!

df_small.drop(['product_name','department'],axis=1, inplace = True)

# %%
df_small.head()
# Out:
#           Unnamed: 0  order_id  product_id  add_to_cart_order  reordered  \
# 2505459      2505459    264199       21137           0.010753          1
# 9974076      9974076   1053143       13964           0.096774          0
# 23108336    23108336   2437202        6193           0.064516          1
# 20201978    20201978   2130882        1559           0.032258          1
# 6808827      6808827    718647       14306           0.150538          0
#
#           user_id  order_number  days_since_prior_order  aisle_id  \
# 2505459    142723      0.101010                1.000000        24
# 9974076     42699      0.050505                0.166667        37
# 23108336   185910      0.383838                0.100000        21
# 20201978    98891      0.020202                0.200000       120
# 6808827    180594      0.070707                0.900000       110
#
#           department_id          ...           order_hour_of_day_14  \
# 2505459               4          ...                              0
# 9974076               1          ...                              0
# 23108336             16          ...                              0
# 20201978             16          ...                              0
# 6808827              13          ...                              0
#
#           order_hour_of_day_15  order_hour_of_day_16  order_hour_of_day_17  \
# 2505459                      0                     0                     0
# 9974076                      0                     0                     0
# 23108336                     0                     0                     0
# 20201978                     0                     0                     0
# 6808827                      0                     1                     0
#
#           order_hour_of_day_18  order_hour_of_day_19  order_hour_of_day_20  \
# 2505459                      0                     0                     0
# 9974076                      0                     0                     0
# 23108336                     0                     0                     0
# 20201978                     0                     0                     0
# 6808827                      0                     0                     0
#
#           order_hour_of_day_21  order_hour_of_day_22  order_hour_of_day_23
# 2505459                      0                     0                     0
# 9974076                      0                     0                     0
# 23108336                     0                     0                     0
# 20201978                     0                     0                     0
# 6808827                      0                     0                     0
#
# [5 rows x 41 columns]

# %%
df_small.drop(['Unnamed: 0'], axis = 1, inplace = True)

# %%
#Helper to index columns before embeddings
def val2idx(df, cols):
    val_types = dict()
    for c in cols:
        val_types[c] = df[c].unique()

    val_to_idx = dict()
    for k, v in val_types.items():
        val_to_idx[k] = {o: i for i, o in enumerate(val_types[k])}

    for k, v in val_to_idx.items():
        df[k] = df[k].apply(lambda x: v[x])

    unique_vals = dict()
    for c in cols:
        unique_vals[c] = df[c].nunique()

    return df, unique_vals

# %%
#Using Keras layer to create Embeddings
def embedding_input(name, n_in, n_out, reg):
    inp = Input(shape=(1,), dtype='int64', name=name)
    return inp, Embedding(n_in, n_out, input_length=1, embeddings_regularizer=l2(reg))(inp)

# %%
#Input layers for continuous vectors to the deep network
def continous_input(name):
    inp = Input(shape=(1,), dtype='float32', name=name)
    return inp, Reshape((1, 1))(inp)

# %%
df_small.isnull().sum().sum()
# Out:
# 0

# %%
df_deep, unique_vals = val2idx(df_small, EMBEDDING_COLUMNS)

# %%
df_deep.head
# Out:
# <bound method NDFrame.head of           order_id  product_id  add_to_cart_order  reordered  user_id  \
# 2505459     264199           0           0.010753          1        0
# 9974076    1053143           1           0.096774          0        1
# 23108336   2437202           2           0.064516          1        2
# 20201978   2130882           3           0.032258          1        3
# 6808827     718647           4           0.150538          0        4
# 33168623   1805524           5           0.129032          0        5
# 24187239   2550975           6           0.010753          1        6
# 14888893   1570962           7           0.000000          1        7
# 1872704     197499           0           0.043011          1        8
# 1312464     138440           8           0.129032          0        9
# 5505383     581077           9           0.161290          0       10
# 21411641   2258508          10           0.000000          0       11
# 890090       94136          11           0.118280          1       12
# 1763033     185881          12           0.000000          1       13
# 31400962   3311989          13           0.000000          1       14
# 27831126   2934895          14           0.032258          1       15
# 11778066   1243479          15           0.354839          0       16
# 19050691   2009255          16           0.021505          1       17
# 8672488     915516          17           0.000000          0       18
# 19468940   2053463          18           0.000000          0       19
# 32090127   3384843          19           0.010753          0       20
# 23924173   2523136          20           0.021505          1       21
# 28610199   3017276          21           0.107527          1       22
# 18893084   1992683          22           0.021505          1       23
# 8635421     911645          23           0.032258          0       24
# 5716526     603436          24           0.000000          1       25
# 7290068     769643          25           0.010753          1       26
# 7399690     781145          26           0.032258          0       27
# 27031734   2850305          27           0.000000          1       28
# 27341082   2883068          28           0.096774          1       29
# ...            ...         ...                ...        ...      ...
# 214916       22690        6794           0.064516          1    60762
# 2525134     266310        3176           0.064516          1    37604
# 145059       15260          77           0.032258          1    30245
# 23281620   2455519        8522           0.010753          1   106956
# 5886282     621311         136           0.032258          1     6439
# 21618853   2280454         151           0.043011          1    31396
# 17776193   1874841        1846           0.010753          1   108346
# 10358353   1093566        2092           0.268817          0    25822
# 9740109    1028278        1756           0.086022          1     4239
# 9615714    1015084       12634           0.064516          0    41093
# 18375930   1938275         260           0.075269          1    60113
# 28742543   3031261         579           0.118280          1    42963
# 7548113     796786        2420           0.075269          1    23811
# 32379393   3415336        5433           0.075269          0    47967
# 20771708   2191128        8750           0.075269          0    72244
# 24230389   2555391        1321           0.182796          0    22309
# 20183594   2128932         165           0.053763          1    95028
# 9771928    1031799        1575           0.096774          0     4852
# 29021568   3060789        3833           0.129032          0    77136
# 32522006    217816        2274           0.086022          1    25774
# 18905000   1993911        5988           0.161290          0     8897
# 27265810   2875121        6276           0.161290          0   123103
# 3323853     351058           6           0.032258          1     7980
# 13260405   1399437         304           0.000000          0     3761
# 21111473   2226797         884           0.086022          0    19218
# 21089002   2224429        7351           0.258065          1    20515
# 17731179   1870015        6058           0.182796          1    10826
# 20840538   2198437        4319           0.333333          0    11538
# 20174574   2127914       11946           0.000000          0    86698
# 19885249   2097341       25890           0.182796          1    13370
#
#           order_number  days_since_prior_order  aisle_id  department_id  \
# 2505459       0.101010                1.000000         0              0
# 9974076       0.050505                0.166667         1              1
# 23108336      0.383838                0.100000         2              2
# 20201978      0.020202                0.200000         3              2
# 6808827       0.070707                0.900000         4              3
# 33168623      0.030303                1.000000         5              0
# 24187239      0.181818                1.000000         0              0
# 14888893      0.040404                0.200000         6              4
# 1872704       0.040404                0.800000         0              0
# 1312464       0.050505                0.333333         7              4
# 5505383       0.333333                0.200000         8              5
# 21411641      0.303030                0.200000         2              2
# 890090        0.191919                0.100000         9              6
# 1763033       0.646465                0.300000        10              6
# 31400962      0.070707                0.100000        11              7
# 27831126      0.101010                0.266667        12              8
# 11778066      0.050505                0.400000        13              6
# 19050691      0.050505                0.466667         5              0
# 8672488       0.050505                0.400000        14              9
# 19468940      0.000000                0.378805         3              2
# 32090127      0.121212                0.200000        15              0
# 23924173      0.121212                0.500000        16              0
# 28610199      0.080808                0.300000        14              9
# 18893084      0.363636                0.066667         3              2
# 8635421       0.030303                1.000000        17             10
# 5716526       0.040404                0.033333        18              2
# 7290068       0.101010                1.000000        19              6
# 7399690       0.020202                0.166667        20             11
# 27031734      0.101010                0.433333        21              6
# 27341082      0.191919                0.100000        22              4
# ...                ...                     ...       ...            ...
# 214916        0.111111                0.133333        30              1
# 2525134       0.131313                0.500000        40              3
# 145059        0.080808                0.266667         0              0
# 23281620      0.252525                0.266667        49              4
# 5886282       0.262626                0.400000        15              0
# 21618853      0.181818                0.033333         0              0
# 17776193      0.222222                0.266667         7              4
# 10358353      0.161616                1.000000        25              2
# 9740109       0.222222                0.266667        64              2
# 9615714       0.000000                0.378805        14              9
# 18375930      0.464646                0.166667         2              2
# 28742543      0.323232                0.233333         5              0
# 7548113       0.636364                0.100000         2              2
# 32379393      0.020202                0.133333        12              8
# 20771708      0.101010                0.766667        12              8
# 24230389      0.030303                0.066667        10              6
# 20183594      0.020202                1.000000         7              4
# 9771928       0.171717                0.233333         6              4
# 29021568      0.000000                0.378805        98             17
# 32522006      0.030303                0.833333        37             11
# 18905000      0.060606                0.833333         3              2
# 27265810      0.000000                0.378805        37             11
# 3323853       0.212121                0.100000         0              0
# 13260405      0.121212                0.766667        18              2
# 21111473      0.383838                0.266667        26              3
# 21089002      0.020202                0.300000        44             16
# 17731179      0.141414                0.200000        59              4
# 20840538      0.424242                0.233333         2              2
# 20174574      0.010101                1.000000        44             16
# 19885249      0.363636                0.266667        99             19
#
#           order_dow_0          ...           order_hour_of_day_14  \
# 2505459             0          ...                              0
# 9974076             0          ...                              0
# 23108336            0          ...                              0
# 20201978            0          ...                              0
# 6808827             1          ...                              0
# 33168623            1          ...                              0
# 24187239            0          ...                              1
# 14888893            0          ...                              0
# 1872704             0          ...                              0
# 1312464             0          ...                              0
# 5505383             0          ...                              0
# 21411641            0          ...                              0
# 890090              0          ...                              0
# 1763033             0          ...                              1
# 31400962            1          ...                              0
# 27831126            0          ...                              0
# 11778066            0          ...                              0
# 19050691            1          ...                              0
# 8672488             0          ...                              0
# 19468940            0          ...                              0
# 32090127            0          ...                              0
# 23924173            0          ...                              0
# 28610199            0          ...                              0
# 18893084            0          ...                              0
# 8635421             1          ...                              0
# 5716526             0          ...                              0
# 7290068             0          ...                              0
# 7399690             0          ...                              0
# 27031734            0          ...                              0
# 27341082            0          ...                              0
True)

# %%
X_train, X_test, y_train, y_test = train_test_split(df_deep, y, test_size=0.25, random_state=42, stratify=y)

# %%
X_train.head()
# Out:
#           order_id  product_id  add_to_cart_order  user_id  order_number  \
# 33197896   1879325         468           0.032258    20294      0.151515
# 6956808     734549        1522           0.021505     5769      0.262626
# 30737153   3242185        6493           0.000000     5158      0.070707
# 29062642   3065077        8949           0.849462    25460      0.272727
# 10668936   1126287         344           0.043011    46988      0.090909
#
#           days_since_prior_order  aisle_id  department_id  order_dow_0  \
# 33197896                0.066667        16              0            0
# 6956808                 0.200000        15              0            1
# 30737153                1.000000        54              3            0
# 29062642                0.100000        63             12            0
# 10668936                0.366667        26              3            0
#
#           order_dow_1          ...           order_hour_of_day_14  \
# 33197896            0          ...                              0
# 6956808             0          ...                              0
# 30737153            0          ...                              0
# 29062642            0          ...                              0
# 10668936            0          ...                              0
#
#           order_hour_of_day_15  order_hour_of_day_16  order_hour_of_day_17  \
# 33197896                     0                     1                     0
# 6956808                      0                     0                     0
# 30737153                     0                     0                     0
# 29062642                     0                     0                     0
# 10668936                     0                     0                     0
#
#           order_hour_of_day_18  order_hour_of_day_19  order_hour_of_day_20  \
# 33197896                     0                     0                     0
# 6956808                      0                     0                     0
# 30737153                     0                     0                     0
# 29062642                     0                     0                     0
# 10668936                     0                     0                     0
#
#           order_hour_of_day_21  order_hour_of_day_22  order_hour_of_day_23
# 33197896                     0                     0                     0
# 6956808                      0                     0                     0
# 30737153                     0                     0                     0
# 29062642                     0                     1                     0
# 10668936                     0                     0                     0
#
# [5 rows x 39 columns]

# %%
#Defining input column for the deep network
#DEEP_COLNS = EMBEDDING_COLUMNS + CONTINUOUS_COLUMNS

# %%
#Creating input dataframe for the merged model
X_train_deep = [X_train[c] for c in X_train.columns]
y_train_deep = np.array(y_train).reshape(-1, 1)
X_test_deep = [X_test[c] for c in X_test.columns]
y_test_deep = np.array(y_test).reshape(-1, 1)

# %%
#Building input tensors for deep network
embeddings_tensors = []
n_factors = 8
reg = 1e-3

for ec in EMBEDDING_COLUMNS:
    layer_name = ec + '_inp'
    t_inp, t_build = embedding_input(layer_name, unique_vals[ec], n_factors, reg)
    embeddings_tensors.append((t_inp, t_build))
    del(t_inp, t_build)
    
continuous_tensors = []
for cc not in EMBEDDING_COLUMNS:
    layer_name = cc + '_in'
    t_inp, t_build = continous_input(layer_name)
    continuous_tensors.append((t_inp, t_build))
    del(t_inp, t_build)
    
deep_inp_layer =  [et[0] for et in embeddings_tensors]
deep_inp_layer += [ct[0] for ct in continuous_tensors]
deep_inp_embed =  [et[1] for et in embeddings_tensors]
deep_inp_embed += [ct[1] for ct in continuous_tensors]
# Out:
#   File "<ipython-input-87-336758d46629>", line 13
#     for cc not in EMBEDDING_COLUMNS:
#              ^
# SyntaxError: invalid syntax

# %%
#Building input tensors for deep network
input_tensors = []

n_factors = 8
reg = 1e-3

for col in X_train.columns:
    if col in EMBEDDING_COLUMNS:
        layer_name = col + '_inp'
        t_inp, t_build = embedding_input(layer_name, unique_vals[col], n_factors, reg)
        input_tensors.append((t_inp, t_build))
        del(t_inp, t_build)
    else:
        layer_name = col + '_in'
        t_inp, t_build = continous_input(layer_name)
        input_tensors.append((t_inp, t_build))
        del(t_inp, t_build)

# %%
deep_input_tensors =  [t[0] for t in input_tensors]
deep_merge_tensors = [t[1] for t in input_tensors]

# %%
#Modeling vanilla neural network with dropout
dropout_prob = 0.2
output_classes = 1

#Layers
x = merge(deep_merge_tensors, mode = 'concat')
x = Flatten()(x)
# 2_. layer to normalise continous columns with the embeddings
x = BatchNormalization()(x)
x = Dropout(dropout_prob)(x,training=True)
x = Dense(100, activation='relu', kernel_regularizer=l1_l2(l1=0.01, l2=0.01))(x)
x = BatchNormalization()(x)
x = Dropout(dropout_prob)(x, training=True)
x = Dense(50, activation='relu')(x)

x = BatchNormalization()(x)
x = Dropout(dropout_prob)(x, training=True)

logits = Dense(output_classes)(x)
variance_pre = Dense(1)(x)
variance = Activation('softplus', name='variance')(variance_pre)
logits_variance = concatenate([logits, variance], name='logits_variance')
softmax_output = Activation('softmax', name='softmax_output')(logits)

model = Model(inputs=deep_input_tensors, outputs=[softmax_output])
# Out:
# /Users/BharathiSrinivasan/anaconda2/envs/python36/lib/python3.6/site-packages/ipykernel_launcher.py:6: UserWarning: The `merge` function is deprecated and will be removed after 08/2017. Use instead layers from `keras.layers.merge`, e.g. `add`, `concatenate`, etc.
#
# /Users/BharathiSrinivasan/anaconda2/envs/python36/lib/python3.6/site-packages/keras/legacy/layers.py:464: UserWarning: The `Merge` layer is deprecated and will be removed after 08/2017. Use instead layers from `keras.layers.merge`, e.g. `add`, `concatenate`, etc.
#   name=name)

# %%
print(model.summary())
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# order_id_in (InputLayer)        (None, 1)            0
# __________________________________________________________________________________________________
# product_id_inp (InputLayer)     (None, 1)            0
# __________________________________________________________________________________________________
# add_to_cart_order_in (InputLaye (None, 1)            0
# __________________________________________________________________________________________________
# user_id_inp (InputLayer)        (None, 1)            0
# __________________________________________________________________________________________________
# order_number_in (InputLayer)    (None, 1)            0
# __________________________________________________________________________________________________
# days_since_prior_order_in (Inpu (None, 1)            0
# __________________________________________________________________________________________________
# aisle_id_inp (InputLayer)       (None, 1)            0
# __________________________________________________________________________________________________
# department_id_inp (InputLayer)  (None, 1)            0
# __________________________________________________________________________________________________
# order_dow_0_in (InputLayer)     (None, 1)            0
# __________________________________________________________________________________________________
# order_dow_1_in (InputLayer)     (None, 1)            0
# __________________________________________________________________________________________________
# order_dow_2_in (InputLayer)     (None, 1)            0
# __________________________________________________________________________________________________
# order_dow_3_in (InputLayer)     (None, 1)            0
# __________________________________________________________________________________________________
# order_dow_4_in (InputLayer)     (None, 1)            0
# __________________________________________________________________________________________________
# order_dow_5_in (InputLayer)     (None, 1)            0
# __________________________________________________________________________________________________
# order_dow_6_in (InputLayer)     (None, 1)            0
# __________________________________________________________________________________________________
# order_hour_of_day_0_in (InputLa (None, 1)            0
# __________________________________________________________________________________________________
# order_hour_of_day_1_in (InputLa (None, 1)            0
# __________________________________________________________________________________________________
# order_hour_of_day_2_in (InputLa (None, 1)            0
# __________________________________________________________________________________________________
# order_hour_of_day_3_in (InputLa (None, 1)            0
# __________________________________________________________________________________________________
# order_hour_of_day_4_in (InputLa (None, 1)            0
# __________________________________________________________________________________________________
# order_hour_of_day_5_in (InputLa (None, 1)            0
# __________________________________________________________________________________________________
# order_hour_of_day_6_in (InputLa (None, 1)            0
# __________________________________________________________________________________________________
# order_hour_of_day_7_in (InputLa (None, 1)            0
# __________________________________________________________________________________________________
# order_hour_of_day_8_in (InputLa (None, 1)            0
# __________________________________________________________________________________________________
# order_hour_of_day_9_in (InputLa (None, 1)            0
# __________________________________________________________________________________________________
# order_hour_of_day_10_in (InputL (None, 1)            0
# __________________________________________________________________________________________________
# order_hour_of_day_11_in (InputL (None, 1)            0
# __________________________________________________________________________________________________
# order_hour_of_day_12_in (InputL (None, 1)            0
# __________________________________________________________________________________________________
# order_hour_of_day_13_in (InputL (None, 1)            0
# __________________________________________________________________________________________________
# order_hour_of_day_14_in (InputL (None, 1)            0
# __________________________________________________________________________________________________
# order_hour_of_day_15_in (InputL (None, 1)            0
# __________________________________________________________________________________________________
# order_hour_of_day_16_in (InputL (None, 1)            0
# __________________________________________________________________________________________________
# order_hour_of_day_17_in (InputL (None, 1)            0
# __________________________________________________________________________________________________
# order_hour_of_day_18_in (InputL (None, 1)            0
# __________________________________________________________________________________________________
# order_hour_of_day_19_in (InputL (None, 1)            0
# __________________________________________________________________________________________________
# order_hour_of_day_20_in (InputL (None, 1)            0
# __________________________________________________________________________________________________
# order_hour_of_day_21_in (InputL (None, 1)            0
# __________________________________________________________________________________________________
# order_hour_of_day_22_in (InputL (None, 1)            0
# __________________________________________________________________________________________________
# order_hour_of_day_23_in (InputL (None, 1)            0
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (None, 1, 1)         0           order_id_in[0][0]
# __________________________________________________________________________________________________
# embedding_1 (Embedding)         (None, 1, 8)         207128      product_id_inp[0][0]
# __________________________________________________________________________________________________
# reshape_2 (Reshape)             (None, 1, 1)         0           add_to_cart_order_in[0][0]
# __________________________________________________________________________________________________
# embedding_2 (Embedding)         (None, 1, 8)         984832      user_id_inp[0][0]
# __________________________________________________________________________________________________
# reshape_3 (Reshape)             (None, 1, 1)         0           order_number_in[0][0]
# __________________________________________________________________________________________________
# reshape_4 (Reshape)             (None, 1, 1)         0           days_since_prior_order_in[0][0]
# __________________________________________________________________________________________________
# embedding_3 (Embedding)         (None, 1, 8)         1072        aisle_id_inp[0][0]
# __________________________________________________________________________________________________
# embedding_4 (Embedding)         (None, 1, 8)         168         department_id_inp[0][0]
# __________________________________________________________________________________________________
# reshape_5 (Reshape)             (None, 1, 1)         0           order_dow_0_in[0][0]
# __________________________________________________________________________________________________
# reshape_6 (Reshape)             (None, 1, 1)         0           order_dow_1_in[0][0]
# __________________________________________________________________________________________________
# reshape_7 (Reshape)             (None, 1, 1)         0           order_dow_2_in[0][0]
# __________________________________________________________________________________________________
# reshape_8 (Reshape)             (None, 1, 1)         0           order_dow_3_in[0][0]
# __________________________________________________________________________________________________
# reshape_9 (Reshape)             (None, 1, 1)         0           order_dow_4_in[0][0]
# __________________________________________________________________________________________________
# reshape_10 (Reshape)            (None, 1, 1)         0           order_dow_5_in[0][0]
# __________________________________________________________________________________________________
# reshape_11 (Reshape)            (None, 1, 1)         0           order_dow_6_in[0][0]
# __________________________________________________________________________________________________
# reshape_12 (Reshape)            (None, 1, 1)         0           order_hour_of_day_0_in[0][0]
# __________________________________________________________________________________________________
# reshape_13 (Reshape)            (None, 1, 1)         0           order_hour_of_day_1_in[0][0]
# __________________________________________________________________________________________________
# reshape_14 (Reshape)            (None, 1, 1)         0           order_hour_of_day_2_in[0][0]
# __________________________________________________________________________________________________
# reshape_15 (Reshape)            (None, 1, 1)         0           order_hour_of_day_3_in[0][0]
# __________________________________________________________________________________________________
# reshape_16 (Reshape)            (None, 1, 1)         0           order_hour_of_day_4_in[0][0]
# __________________________________________________________________________________________________
# reshape_17 (Reshape)            (None, 1, 1)         0           order_hour_of_day_5_in[0][0]
# __________________________________________________________________________________________________
# reshape_18 (Reshape)            (None, 1, 1)         0           order_hour_of_day_6_in[0][0]
# __________________________________________________________________________________________________
# reshape_19 (Reshape)            (None, 1, 1)         0           order_hour_of_day_7_in[0][0]
# __________________________________________________________________________________________________
# reshape_20 (Reshape)            (None, 1, 1)         0           order_hour_of_day_8_in[0][0]
# __________________________________________________________________________________________________
# reshape_21 (Reshape)            (None, 1, 1)         0           order_hour_of_day_9_in[0][0]
# __________________________________________________________________________________________________
# reshape_22 (Reshape)            (None, 1, 1)         0           order_hour_of_day_10_in[0][0]
# __________________________________________________________________________________________________
# reshape_23 (Reshape)            (None, 1, 1)         0           order_hour_of_day_11_in[0][0]
# __________________________________________________________________________________________________
# reshape_24 (Reshape)            (None, 1, 1)         0           order_hour_of_day_12_in[0][0]
# __________________________________________________________________________________________________
# reshape_25 (Reshape)            (None, 1, 1)         0           order_hour_of_day_13_in[0][0]
# __________________________________________________________________________________________________
# reshape_26 (Reshape)            (None, 1, 1)         0           order_hour_of_day_14_in[0][0]
# __________________________________________________________________________________________________
# reshape_27 (Reshape)            (None, 1, 1)         0           order_hour_of_day_15_in[0][0]
# __________________________________________________________________________________________________
# reshape_28 (Reshape)            (None, 1, 1)         0           order_hour_of_day_16_in[0][0]
# __________________________________________________________________________________________________
# reshape_29 (Reshape)            (None, 1, 1)         0           order_hour_of_day_17_in[0][0]
# __________________________________________________________________________________________________
# reshape_30 (Reshape)            (None, 1, 1)         0           order_hour_of_day_18_in[0][0]
# __________________________________________________________________________________________________
# reshape_31 (Reshape)            (None, 1, 1)         0           order_hour_of_day_19_in[0][0]
# __________________________________________________________________________________________________
# reshape_32 (Reshape)            (None, 1, 1)         0           order_hour_of_day_20_in[0][0]
# __________________________________________________________________________________________________
# reshape_33 (Reshape)            (None, 1, 1)         0           order_hour_of_day_21_in[0][0]
# __________________________________________________________________________________________________
# reshape_34 (Reshape)            (None, 1, 1)         0           order_hour_of_day_22_in[0][0]
# __________________________________________________________________________________________________
# reshape_35 (Reshape)            (None, 1, 1)         0           order_hour_of_day_23_in[0][0]
# __________________________________________________________________________________________________
# merge_3 (Merge)                 (None, 1, 67)        0           reshape_1[0][0]
#                                                                  embedding_1[0][0]
#                                                                  reshape_2[0][0]
#                                                                  embedding_2[0][0]
#                                                                  reshape_3[0][0]
#                                                                  reshape_4[0][0]
#                                                                  embedding_3[0][0]
#                                                                  embedding_4[0][0]
#                                                                  reshape_5[0][0]
#                                                                  reshape_6[0][0]
#                                                                  reshape_7[0][0]
#                                                                  reshape_8[0][0]
#                                                                  reshape_9[0][0]
#                                                                  reshape_10[0][0]
#                                                                  reshape_11[0][0]
#                                                                  reshape_12[0][0]
#                                                                  reshape_13[0][0]
#                                                                  reshape_14[0][0]
#                                                                  reshape_15[0][0]
#                                                                  reshape_16[0][0]
#                                                                  reshape_17[0][0]
#                                                                  reshape_18[0][0]
#                                                                  reshape_19[0][0]
#                                                                  reshape_20[0][0]
#                                                                  reshape_21[0][0]
#                                                                  reshape_22[0][0]
#                                                                  reshape_23[0][0]
#                                                                  reshape_24[0][0]
#                                                                  reshape_25[0][0]
#                                                                  reshape_26[0][0]
#                                                                  reshape_27[0][0]
#                                                                  reshape_28[0][0]
#                                                                  reshape_29[0][0]
#                                                                  reshape_30[0][0]
#                                                                  reshape_31[0][0]
#                                                                  reshape_32[0][0]
#                                                                  reshape_33[0][0]
#                                                                  reshape_34[0][0]
#                                                                  reshape_35[0][0]
# __________________________________________________________________________________________________
# flatten_3 (Flatten)             (None, 67)           0           merge_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 67)           268         flatten_3[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 67)           0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (None, 100)          6800        dropout_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 100)          400         dense_9[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 100)          0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# dense_10 (Dense)                (None, 50)           5050        dropout_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 50)           200         dense_10[0][0]
# __________________________________________________________________________________________________
# dropout_9 (Dropout)             (None, 50)           0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# dense_11 (Dense)                (None, 1)            51          dropout_9[0][0]
# __________________________________________________________________________________________________
# softmax_output (Activation)     (None, 1)            0           dense_11[0][0]
# ==================================================================================================
# Total params: 1,205,969
# Trainable params: 1,205,535
# Non-trainable params: 434
# __________________________________________________________________________________________________
# None

# %%
from keras.utils.vis_utils import plot_model

# %%
model.compile(optimizer='sgd', loss='binary_crossentropy', metrics=['accuracy'])

# %%
len(X_train_deep)
# Out:
# 39

# %%
len(y_train_deep)
# Out:
# 253643

# %%
model.fit(X_train_deep, y_train_deep, batch_size=64, epochs=1)
# Out:
# Epoch 1/1
# 253643/253643 [==============================] - 108s 427us/step - loss: 8.4263 - acc: 0.5879

# %%
def CrossEntropy(yHat, y):
    if y == 1:
          return -log(yHat)
    else:
          return -log(1 - yHat)

# %%
def predictor(model, 
              X_test = X_test_deep, y_test = y_test_deep, T = 10):
    probs_mc_dropout = []
    for _ in range(T):
        probs_mc_dropout += [model.predict(X_test,verbose=0)]
    #predictive_mean = np.mean(probs_mc_dropout, axis=0)
    #predictive_variance = np.var(probs_mc_dropout, axis=0)
    #logloss_mc_dropout = CrossEntropy(predictive_mean, y_test)
    #print(logloss_mc_dropout)
  
    return probs_mc_dropout

# %%
probs_mc_dropout = predictor(model)

# %%
predictive_mean = np.mean(probs_mc_dropout, axis=0)
predictive_variance = np.var(probs_mc_dropout, axis=0)

# %%
from sklearn import metrics
print(metrics.precision_score(y_test_deep, predictive_mean))
# Out:
# 0.5878554194067276

# %%
print(metrics.recall_score(y_test_deep, predictive_mean))
# Out:
# 1.0

# %%
print(metrics.roc_auc_score(y_test_deep, predictive_mean))
# Out:
# 0.5
